# %%
import numpy as np
import pandas as pd
import os
import random
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
register_matplotlib_converters()

from statsmodels.tsa.vector_ar.var_model import VAR

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator



import statsmodels.api as sm


gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 1., allow_growth=True)
   
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
os.chdir('/home/nnlinux/Documentos/git-repos/doutorado/phD-thesis-project/')

# %%
### READ DATA ###

# Carrega os dados
github_repo = 'https://raw.githubusercontent.com/carlosvneves/doutorado/master/'
desembolsos = pd.read_csv(github_repo + 'desembolsos.csv')
pib = pd.read_csv(github_repo +'pib.csv')
fbcf = pd.read_csv(github_repo +'fbcf.csv') 

fbcf.index = pd.to_datetime(fbcf['date'])
fbcf.drop(['date'],inplace=True, axis = 1)

    
pib.index = pd.to_datetime(pib['date'])
pib.drop(['date'],inplace=True, axis = 1)


desembolsos.index = pd.to_datetime(desembolsos['date'])
desembolsos.drop(['date'], inplace=True, axis = 1)
    
data = desembolsos.groupby(pd.PeriodIndex(desembolsos.index, freq='Q')).mean()
data = data.loc['1996Q1':]
data.index = data.index.to_timestamp(freq='Q')

for col in data.columns:
    data[col] = data[col]/pib['pib'].values * 100
    
    
# Corte da série de acordo com a análise de tendência
start = '2002Q1'

data['Investimento'] = fbcf['fbcf'].values/pib['pib'].values *100
data = data.loc[start:]

print(data.describe())


# Visualiza os dados originais
plt.figure()
plt.plot(data.index,data[['Investimento']],
          label = 'Investimentos como % do PIB')
plt.xlabel('Ano')
plt.ylabel('FBCF (%PIB)')
plt.legend()
plt.title('Formação Bruta de Capital Fixo como % do PIB')
#plt.savefig('investimentos')
plt.show()

plt.figure()
plt.plot(data.index,data[['Agropecuária']],
          label = 'Aropecuária como % do PIB')
plt.plot(data.index,data[['Indústria']],
          label = 'Induśtria como % do PIB')
plt.plot(data.index,data[['Infraestrutura']],
          label = 'Infraestrutura como % do PIB')
plt.plot(data.index,data[['Comércio e serviços']],
          label = 'Comércio e Serviços como % do PIB')
plt.plot(data.index,data[['Total']],
          label = 'Total como % do PIB')
plt.title('Desembolsos do BNDES como % do PIB')
plt.xlabel('Ano')
plt.ylabel('FBCF (%PIB)')
plt.legend()
#plt.savefig('desembolsos')
plt.show()
  


data[['Agropecuária','Indústria','Infraestrutura','Comércio e serviços', 'Total']]


# Ajuste Sazonal (X-13 ARIMA) das séries para otimizar a modelagem
X13_PATH = os.path.join('x13/')

data_sa = pd.DataFrame(data)
data_sa.rename(columns=lambda x: x[0:3], inplace=True)

for col in data_sa:
  sa = sm.tsa.x13_arima_analysis(data_sa[col],x12path=X13_PATH)
  data_sa[col] = sa.seasadj.values

data_sa.tail()


# Visualiza dados com ajuste sazonal 

plt.figure()
plt.plot(data_sa.index,data_sa[['Inv']],
        label = 'Investimentos como % do PIB')
plt.xlabel('Ano')
plt.ylabel('FBCF (%PIB)')
plt.legend()
plt.title('Formação Bruta de Capital Fixo como % do PIB - ajuste sazonal')
#plt.savefig('investimentos-sa')
plt.show()

plt.figure()
plt.plot(data_sa.index,data_sa[['Agr']],
        label = 'Aropecuária como % do PIB')
plt.plot(data_sa.index,data_sa[['Ind']],
        label = 'Induśtria como % do PIB')
plt.plot(data_sa.index,data_sa[['Inf']],
        label = 'Infraestrutura como % do PIB')
plt.plot(data_sa.index,data_sa[['Com']],
        label = 'Comércio e Serviços como % do PIB')
plt.plot(data_sa.index,data_sa[['Tot']],
        label = 'Total como % do PIB')
plt.title('Desembolsos do BNDES como % do PIB - ajuste sazonal')
plt.xlabel('Ano')
plt.ylabel('FBCF (%PIB)')
plt.legend()
#plt.savefig('desembolsos-sa')
plt.show() 
#  Unsample dos dados de Trim para Mensal
upsampled = data_sa.resample('M')
interpolated = upsampled.interpolate(method='linear')
interpolated.tail(24)

data = interpolated
data = data[['Inv','Agr','Ind','Inf','Com']]
data.head()
# Out:
#        Agropecuária  Indústria  Infraestrutura  Comércio e serviços  \
# count     72.000000  72.000000       72.000000            72.000000
# mean       0.135622   0.565348        0.495093             0.219978
# std        0.065522   0.458333        0.270936             0.153548
# min        0.053407   0.028426        0.085215             0.022447
# 25%        0.091239   0.265550        0.274034             0.104358
# 50%        0.118062   0.540207        0.491297             0.175733
# 75%        0.149423   0.709280        0.658696             0.336986
# max        0.370092   2.638441        1.143117             0.832406
#
#            Total  Investimento
# count  72.000000     72.000000
# mean    1.416042     17.987601
# std     0.779904      2.096092
# min     0.202680     14.268541
# 25%     0.939751     16.376876
# 50%     1.439447     17.847753
# 75%     1.773297     20.039805
# max     3.913393     21.525857
#                   Inv       Agr       Ind       Inf       Com
# date
# 2002-03-31  18.017116  0.231266  0.836440  1.101536  0.135042
# 2002-04-30  18.024239  0.237004  1.004470  0.828353  0.157193
# 2002-05-31  18.031363  0.242741  1.172500  0.555169  0.179344
# 2002-06-30  18.038487  0.248479  1.340529  0.281986  0.201495
# 2002-07-31  17.911289  0.267514  1.397601  0.496783  0.202467

# %%
### ADJUST AND CLEAN DATA ###

df_external = data[['Agr','Ind','Inf','Com']]

df_external.head()
# Out:
#                  Agr       Ind       Inf       Com
# date
# 2002-03-31  0.231266  0.836440  1.101536  0.135042
# 2002-04-30  0.237004  1.004470  0.828353  0.157193
# 2002-05-31  0.242741  1.172500  0.555169  0.179344
# 2002-06-30  0.248479  1.340529  0.281986  0.201495
# 2002-07-31  0.267514  1.397601  0.496783  0.202467

# %%
### SPLIT TRAIN TEST ###
split = 0.75

train_date = data.index[:int(len(data)*split)]
train = data[:int(len(data)*split)].copy()

test_date = data.index[int(len(data)*split):]
test = data[int(len(data)*split):].copy()

print(train.shape, test.shape)
# Out:
# (160, 5) (54, 5)

# %%
### PLOTTING UTILITY FUNCTIONS ###

def plot_sensor(name):
    
    plt.figure(figsize=(16,4))

    plt.plot(train_date, train[name], label='train')
    plt.plot(test_date, test[name], label='test')
    plt.ylabel(name); plt.legend()
    plt.show()
    
def plot_autocor(name, df):
    
    plt.figure(figsize=(16,4))
    
    # pd.plotting.autocorrelation_plot(df[name])
    # plt.title(name)
    # plt.show()
    
    timeLags = np.arange(1,100*24)
    plt.plot([df[name].autocorr(dt) for dt in timeLags])
    plt.title(name); plt.ylabel('autocorr'); plt.xlabel('time lags')
    plt.show()

# %%
### PLOT ORIGINAL SERIES ###

for col in data.columns:
    plot_sensor(col)

# %%
### PLOT AUTOCORRELATION ###

for col in data.columns:
    plot_autocor(col, train)
# Out:
# /home/nnlinux/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/nnlinux/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
### OPERATE DIFFERENTIATION ###
period = 1

df_diff = data.diff(period).dropna()
df_external = df_external.iloc[period:].copy()

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.10:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df_diff['Inv'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -2.694556
# p-value                   0.074985
# # lags used              12.000000
# # observations          200.000000
# critical value (1%)      -3.463476
# critical value (5%)      -2.876102
# critical value (10%)     -2.574532
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
adf_test(df_diff['Agr'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -4.338216
# p-value                   0.000381
# # lags used              15.000000
# # observations          197.000000
# critical value (1%)      -3.463987
# critical value (5%)      -2.876326
# critical value (10%)     -2.574652
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
adf_test(df_diff['Ind'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -4.418187
# p-value                   0.000276
# # lags used              15.000000
# # observations          197.000000
# critical value (1%)      -3.463987
# critical value (5%)      -2.876326
# critical value (10%)     -2.574652
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
adf_test(df_diff['Inf'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -4.005986
# p-value                   0.001379
# # lags used              15.000000
# # observations          197.000000
# critical value (1%)      -3.463987
# critical value (5%)      -2.876326
# critical value (10%)     -2.574652
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
adf_test(df_diff['Com'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -2.745439
# p-value                   0.066500
# # lags used              15.000000
# # observations          197.000000
# critical value (1%)      -3.463987
# critical value (5%)      -2.876326
# critical value (10%)     -2.574652
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
### SPLIT DIFFERENTIAL DATA IN TRAIN AND TEST ###

train_diff = df_diff.iloc[:len(train)-period,:].copy()
test_diff = df_diff.iloc[len(train)-period:,:].copy()

train_init = data.iloc[:len(train)-period,:].copy()
test_init = data.iloc[len(train)-period:-period,:].copy()

train_ext = df_external.iloc[:len(train)-period,:].copy()
test_ext = df_external.iloc[len(train)-period:,:].copy()

print(train_diff.shape, train_init.shape, train_ext.shape)
print(test_diff.shape, test_init.shape, test_ext.shape)
# Out:
# (159, 5) (159, 5) (159, 4)
# (54, 5) (54, 5) (54, 4)

# %%
### PLOT DIFFERENTIAL SERIES ###

for col in data.columns:
    plot_autocor(col, train_diff)

# %%
### FIND BEST VAR ORDER ###

AIC = {}
best_aic, best_order = np.inf, 0

for i in range(1,10):
    model = VAR(endog=train_diff.values)
    model_result = model.fit(maxlags=i)
    AIC[i] = model_result.aic
    
    if AIC[i] < best_aic:
        best_aic = AIC[i]
        best_order = i
        
print('BEST ORDER', best_order, 'BEST AIC:', best_aic)
# Out:
# BEST ORDER 7 BEST AIC: -33.995835260118014

# %%
### PLOT AICs ### 

plt.figure(figsize=(14,5))
plt.plot(range(len(AIC)), list(AIC.values()))
plt.plot([best_order-1], [best_aic], marker='o', markersize=8, color="red")
plt.xticks(range(len(AIC)), range(1,50))
plt.xlabel('lags'); plt.ylabel('AIC')
np.set_printoptions(False)

# %%
### FIT FINAL VAR WITH LAG CORRESPONTING TO THE BEST AIC ###

var = VAR(endog=train_diff.values)
var_result = var.fit(maxlags=best_order)
var_result.aic
# Out:
# -33.995835260118014

# %% [markdown]
# # VAR LONG-TERM PREDICTION

# %%
### UTILITY FUNCTION FOR RETRIVE VAR PREDICTIONS ###

def retrive_prediction(prior, prior_init, steps):
    
    pred = var_result.forecast(np.asarray(prior), steps=steps)
    init = prior_init.tail(period).values
    
    if steps > period:
        id_period = list(range(period))*(steps//period)
        id_period = id_period + list(range(steps-len(id_period)))
    else:
        id_period = list(range(steps))
    
    final_pred = np.zeros((steps, prior.shape[1]))
    for j, (i,p) in enumerate(zip(id_period, pred)):
        final_pred[j] = init[i]+p
        init[i] = init[i]+p    
        
    return final_pred

# %%
train_date[-1]
# Out:
# Timestamp('2015-06-30 00:00:00', freq='M')

# %%
### RETRIVE PREDICTION AND OBTAIN THE CORRESPONDING ACTUAL VALUES ###

date = train_date[-1]
forward = test.shape[0]
date_range = pd.date_range(date, periods=forward+1, freq='M', closed='right')

final_pred = retrive_prediction(df_diff.loc[:date], data.loc[:date], steps = forward)
final_true = data.loc[date_range]

# %%
### PLOT ACTUAL vs PREDICTION ###

for i,col in enumerate(data.columns):

    plt.figure(figsize=(16,4))
    plt.plot(date_range, final_pred[:,i], c='green', label='prediction var')
    plt.plot(date_range, final_true[col].values, c='orange', label='true')
    plt.ylabel(col); plt.legend()
    plt.show()

# %% [markdown]
# # COMBINE VAR AND LSTM

# %%
### UTILITY FUNCTIONS FOR NEURAL NETWORK TRAINING ###

def autocor_pred(real, pred, lag=1):
    return pearsonr(real[:-lag], pred[lag:])[0]


seq_length = 36

def get_model():
    
    opt = RMSprop(lr=1e-4)
    
    inp = Input(shape=(seq_length, test.shape[0]))
    
    x = LSTM(300)(inp)
    x = Dropout(0.5)(x)
    x = Dense(175, activation='relu')(x)
    x = Dropout(0.5)(x)
    
    out = Dense(5)(x)
    
    model = Model(inp, out)
    model.compile(optimizer=opt, loss='mse')
    
    return model

# %%
### GET TRAIN VALIDATION AND TEST DATA FOR NEURAL NETWORK ###

X = var_result.fittedvalues

y_train = train.iloc[period+best_order:].values
y_train_var = X + train_init.iloc[best_order:].values
X_train = np.concatenate([train_diff.iloc[best_order:].values, train_ext.iloc[best_order:].values], axis=1)
X_train_var = np.concatenate([X, train_ext.iloc[best_order:].values], axis=1)

y_val = y_train[int(len(X)*split):]
y_val_var = y_train_var[int(len(X)*split):]
X_val = X_train[int(len(X)*split):]
X_val_var = X_train_var[int(len(X)*split):]

y_train = y_train[:int(len(X)*split)]
y_train_var = y_train_var[:int(len(X)*split)]
X_train = X_train[:int(len(X)*split)]
X_train_var = X_train_var[:int(len(X)*split)]

y_test = test.values
X_test = np.concatenate([test_diff.values, test_ext.values], axis=1)

# %%
### SCALE DATA ###

scaler_y = StandardScaler()
scaler = StandardScaler()

y_train = scaler_y.fit_transform(y_train)
y_train_var = scaler_y.transform(y_train_var)
y_val = scaler_y.transform(y_val)
y_val_var = scaler_y.transform(y_val_var)
y_test = scaler_y.transform(y_test)

X_train = scaler.fit_transform(X_train)
X_train_var = scaler.transform(X_train_var)
X_val = scaler.transform(X_val)
X_val_var = scaler.transform(X_val_var)
X_test = scaler.transform(X_test)

# %%
### BUILD DATA GENERATOR ###

generator_train = TimeseriesGenerator(X_train, y_train, length=seq_length, batch_size=32)
generator_train_var = TimeseriesGenerator(X_train_var, y_train_var, length=seq_length, batch_size=32)
generator_val = TimeseriesGenerator(X_val, y_val, length=seq_length, batch_size=32)
generator_val_var = TimeseriesGenerator(X_val_var, y_val_var, length=seq_length, batch_size=32)
generator_test = TimeseriesGenerator(X_test, y_test, length=seq_length, batch_size=32)

# %%
### FIT NEURAL NETWORK WITH VAR FITTED VALUES AND RAW DATA ###

tf.random.set_seed(33)
os.environ['PYTHONHASHSEED'] = str(33)
np.random.seed(33)
random.seed(33)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)


es = EarlyStopping(patience=30, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

print('--------', 'train model with VAR fitted values', '--------')
model_var = get_model()
model_var.fit_generator(generator_train_var, steps_per_epoch= len(generator_train_var),
                        epochs=100, validation_data=generator_val_var, validation_steps = len(generator_val_var), 
                        callbacks=[es], verbose = 1)


print('--------', 'train model with raw data', '--------')
model_var.fit_generator(generator_train, steps_per_epoch= len(generator_train),
                        epochs=100, validation_data=generator_val, validation_steps = len(generator_val), 
                        callbacks=[es], verbose = 1)
# Out:
# -------- train model with VAR fitted values --------
# WARNING:tensorflow:From <ipython-input-29-a974e4311ce1>:25: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 3/3 [==============================] - 0s 109ms/step - loss: 0.9742 - val_loss: 0.7805
# Epoch 2/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9441 - val_loss: 0.7690
# Epoch 3/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9243 - val_loss: 0.7578
# Epoch 4/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9046 - val_loss: 0.7481
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8722 - val_loss: 0.7370
# Epoch 6/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8734 - val_loss: 0.7287
# Epoch 7/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8430 - val_loss: 0.7202
# Epoch 8/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8232 - val_loss: 0.7125
# Epoch 9/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7907 - val_loss: 0.7047
# Epoch 10/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7854 - val_loss: 0.6974
# Epoch 11/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7464 - val_loss: 0.6888
# Epoch 12/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7386 - val_loss: 0.6820
# Epoch 13/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7355 - val_loss: 0.6750
# Epoch 14/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7240 - val_loss: 0.6688
# Epoch 15/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6803 - val_loss: 0.6627
# Epoch 16/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6586 - val_loss: 0.6548
# Epoch 17/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6300 - val_loss: 0.6513
# Epoch 18/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6355 - val_loss: 0.6472
# Epoch 19/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5835 - val_loss: 0.6457
# Epoch 20/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5956 - val_loss: 0.6453
# Epoch 21/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5428 - val_loss: 0.6489
# Epoch 22/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5196 - val_loss: 0.6556
# Epoch 23/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5572 - val_loss: 0.6679
# Epoch 24/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4970 - val_loss: 0.6825
# Epoch 25/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5034 - val_loss: 0.6870
# Epoch 26/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4722 - val_loss: 0.6791
# Epoch 27/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4544 - val_loss: 0.6842
# Epoch 28/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4170 - val_loss: 0.6765
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4640 - val_loss: 0.6440
# Epoch 30/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4699 - val_loss: 0.6405
# Epoch 31/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4134 - val_loss: 0.6374
# Epoch 32/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4375 - val_loss: 0.6267
# Epoch 33/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3976 - val_loss: 0.6401
# Epoch 34/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4041 - val_loss: 0.6020
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4220 - val_loss: 0.6063
# Epoch 36/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4180 - val_loss: 0.5414
# Epoch 37/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3861 - val_loss: 0.5663
# Epoch 38/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3639 - val_loss: 0.5450
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4052 - val_loss: 0.5578
# Epoch 40/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3573 - val_loss: 0.5481
# Epoch 41/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3788 - val_loss: 0.5264
# Epoch 42/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4040 - val_loss: 0.5522
# Epoch 43/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4149 - val_loss: 0.5220
# Epoch 44/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3688 - val_loss: 0.5238
# Epoch 45/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3651 - val_loss: 0.4972
# Epoch 46/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3437 - val_loss: 0.5160
# Epoch 47/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3817 - val_loss: 0.4850
# Epoch 48/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3377 - val_loss: 0.4517
# Epoch 49/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3441 - val_loss: 0.4505
# Epoch 50/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3521 - val_loss: 0.4326
# Epoch 51/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3323 - val_loss: 0.4313
# Epoch 52/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3833 - val_loss: 0.4048
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3360 - val_loss: 0.4222
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3198 - val_loss: 0.4182
# Epoch 55/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3361 - val_loss: 0.3769
# Epoch 56/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3088 - val_loss: 0.3679
# Epoch 57/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3378 - val_loss: 0.3914
# Epoch 58/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3305 - val_loss: 0.3962
# Epoch 59/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3061 - val_loss: 0.4041
# Epoch 60/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3382 - val_loss: 0.3761
# Epoch 61/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3144 - val_loss: 0.4151
# Epoch 62/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3326 - val_loss: 0.3744
# Epoch 63/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3141 - val_loss: 0.3894
# Epoch 64/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3155 - val_loss: 0.3796
# Epoch 65/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3286 - val_loss: 0.3703
# Epoch 66/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3082 - val_loss: 0.3990
# Epoch 67/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2832 - val_loss: 0.3965
# Epoch 68/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3207 - val_loss: 0.3921
# Epoch 69/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2989 - val_loss: 0.3609
# Epoch 70/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3037 - val_loss: 0.3690
# Epoch 71/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2730 - val_loss: 0.3898
# Epoch 72/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2964 - val_loss: 0.4392
# Epoch 73/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2880 - val_loss: 0.4114
# Epoch 74/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3020 - val_loss: 0.3776
# Epoch 75/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2839 - val_loss: 0.3891
# Epoch 76/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2898 - val_loss: 0.4094
# Epoch 77/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2655 - val_loss: 0.3892
# Epoch 78/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2622 - val_loss: 0.4562
# Epoch 79/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2694 - val_loss: 0.3412
# Epoch 80/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2593 - val_loss: 0.3913
# Epoch 81/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3068 - val_loss: 0.3908
# Epoch 82/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2407 - val_loss: 0.4333
# Epoch 83/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2456 - val_loss: 0.4247
# Epoch 84/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2667 - val_loss: 0.4265
# Epoch 85/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2763 - val_loss: 0.3953
# Epoch 86/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2543 - val_loss: 0.4510
# Epoch 87/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2675 - val_loss: 0.4067
# Epoch 88/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2461 - val_loss: 0.4907
# Epoch 89/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2268 - val_loss: 0.4181
# Epoch 90/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2492 - val_loss: 0.3842
# Epoch 91/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2313 - val_loss: 0.4032
# Epoch 92/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2327 - val_loss: 0.4922
# Epoch 93/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2416 - val_loss: 0.5375
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2350 - val_loss: 0.5857
# Epoch 95/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2563 - val_loss: 0.4680
# Epoch 96/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2202 - val_loss: 0.4099
# Epoch 97/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2687 - val_loss: 0.4505
# Epoch 98/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2139 - val_loss: 0.5305
# Epoch 99/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2309 - val_loss: 0.5731
# Epoch 100/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2379 - val_loss: 0.5887
# -------- train model with raw data --------
# Epoch 1/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2432 - val_loss: 0.5302
# Epoch 2/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2270 - val_loss: 0.5792
# Epoch 3/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1976 - val_loss: 0.6068
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1977 - val_loss: 0.4876
# Epoch 5/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2193 - val_loss: 0.4094
# Epoch 6/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1997 - val_loss: 0.4972
# Epoch 7/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2048 - val_loss: 0.6144
# Epoch 8/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1910 - val_loss: 0.4249
# Epoch 9/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2038 - val_loss: 0.5185
# Epoch 10/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1775 - val_loss: 0.4708
# Epoch 11/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2079 - val_loss: 0.4245
# Epoch 12/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1740 - val_loss: 0.4383
# Epoch 13/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1977 - val_loss: 0.2844
# Epoch 14/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2025 - val_loss: 0.3942
# Epoch 15/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1865 - val_loss: 0.3358
# Epoch 16/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1916 - val_loss: 0.3583
# Epoch 17/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1720 - val_loss: 0.4802
# Epoch 18/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1768 - val_loss: 0.3605
# Epoch 19/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1815 - val_loss: 0.4880
# Epoch 20/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1876 - val_loss: 0.5891
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - loss: 0.081 - 0s 13ms/step - loss: 0.1939 - val_loss: 0.4618
# Epoch 22/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1943 - val_loss: 0.5469
# Epoch 23/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1959 - val_loss: 0.5468
# Epoch 24/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1771 - val_loss: 0.7182
# Epoch 25/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1918 - val_loss: 0.4457
# Epoch 26/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1798 - val_loss: 0.5221
# Epoch 27/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1680 - val_loss: 0.4902
# Epoch 28/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2050 - val_loss: 0.4808
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1726 - val_loss: 0.4909
# Epoch 30/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1753 - val_loss: 0.5621
# Epoch 31/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1750 - val_loss: 0.5067
# Epoch 32/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1848 - val_loss: 0.3880
# Epoch 33/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1530 - val_loss: 0.4207
# Epoch 34/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1637 - val_loss: 0.4594
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1971 - val_loss: 0.4826
# Epoch 36/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1727 - val_loss: 0.3917
# Epoch 37/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1778 - val_loss: 0.5007
# Epoch 38/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1633 - val_loss: 0.4463
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1610 - val_loss: 0.3966
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1458 - val_loss: 0.3489
# Epoch 41/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1585 - val_loss: 0.4126
# Epoch 42/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1616 - val_loss: 0.3589
# Epoch 43/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1881Restoring model weights from the end of the best epoch.
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1292 - val_loss: 0.4481
# Epoch 00043: early stopping

# %%
### OBTAIN PREDICTIONS AND RETRIVE ORIGINAL DATA ###

true = scaler_y.inverse_transform(y_test[seq_length:])

pred = model_var.predict_generator(generator_test)
pred = scaler_y.inverse_transform(pred)
# Out:
# WARNING:tensorflow:From <ipython-input-30-35c9cbd1de58>:5: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
plt.plot(pred[:,0])

# %%
### FIT NEURAL NETWORK WITH ONLY ORIGINAL DATA ###

tf.random.set_seed(33)
os.environ['PYTHONHASHSEED'] = str(33)
np.random.seed(33)
random.seed(33)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)


es = EarlyStopping(patience=30, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

simple_model = get_model()
simple_model.fit_generator(generator_train, steps_per_epoch= len(generator_train),
                            epochs=300, validation_data=generator_val, validation_steps = len(generator_val), 
                            callbacks=[es], verbose = 1)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9688 - val_loss: 0.7713
# Epoch 2/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9360 - val_loss: 0.7588
# Epoch 3/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9128 - val_loss: 0.7470
# Epoch 4/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8916 - val_loss: 0.7374
# Epoch 5/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8655 - val_loss: 0.7252
# Epoch 6/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8663 - val_loss: 0.7177
# Epoch 7/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8344 - val_loss: 0.7075
# Epoch 8/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8141 - val_loss: 0.6999
# Epoch 9/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7785 - val_loss: 0.6932
# Epoch 10/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7731 - val_loss: 0.6849
# Epoch 11/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7422 - val_loss: 0.6772
# Epoch 12/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7260 - val_loss: 0.6700
# Epoch 13/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7307 - val_loss: 0.6636
# Epoch 14/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7175 - val_loss: 0.6576
# Epoch 15/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6830 - val_loss: 0.6509
# Epoch 16/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6511 - val_loss: 0.6427
# Epoch 17/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6229 - val_loss: 0.6366
# Epoch 18/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6384 - val_loss: 0.6310
# Epoch 19/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5787 - val_loss: 0.6273
# Epoch 20/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5886 - val_loss: 0.6229
# Epoch 21/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5442 - val_loss: 0.6199
# Epoch 22/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5176 - val_loss: 0.6189
# Epoch 23/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5522 - val_loss: 0.6226
# Epoch 24/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4942 - val_loss: 0.6267
# Epoch 25/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4893 - val_loss: 0.6261
# Epoch 26/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4693 - val_loss: 0.6178
# Epoch 27/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4472 - val_loss: 0.6203
# Epoch 28/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4093 - val_loss: 0.6121
# Epoch 29/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4507 - val_loss: 0.5859
# Epoch 30/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4591 - val_loss: 0.5795
# Epoch 31/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4028 - val_loss: 0.5727
# Epoch 32/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4195 - val_loss: 0.5645
# Epoch 33/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3822 - val_loss: 0.5634
# Epoch 34/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4026 - val_loss: 0.5327
# Epoch 35/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4077 - val_loss: 0.5321
# Epoch 36/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3962 - val_loss: 0.4838
# Epoch 37/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3684 - val_loss: 0.4971
# Epoch 38/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3611 - val_loss: 0.4724
# Epoch 39/300
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3844 - val_loss: 0.4790
# Epoch 40/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3313 - val_loss: 0.4636
# Epoch 41/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3505 - val_loss: 0.4431
# Epoch 42/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3810 - val_loss: 0.4625
# Epoch 43/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3952 - val_loss: 0.4367
# Epoch 44/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3424 - val_loss: 0.4366
# Epoch 45/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3563 - val_loss: 0.4101
# Epoch 46/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3122 - val_loss: 0.4223
# Epoch 47/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3599 - val_loss: 0.3849
# Epoch 48/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3215 - val_loss: 0.3576
# Epoch 49/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3238 - val_loss: 0.3577
# Epoch 50/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3317 - val_loss: 0.3452
# Epoch 51/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3051 - val_loss: 0.3341
# Epoch 52/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3642 - val_loss: 0.3167
# Epoch 53/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3073 - val_loss: 0.3229
# Epoch 54/300
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2915 - val_loss: 0.3172
# Epoch 55/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2971 - val_loss: 0.2782
# Epoch 56/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2782 - val_loss: 0.2672
# Epoch 57/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3109 - val_loss: 0.2819
# Epoch 58/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3100 - val_loss: 0.2947
# Epoch 59/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2771 - val_loss: 0.3030
# Epoch 60/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3006 - val_loss: 0.2795
# Epoch 61/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2719 - val_loss: 0.3086
# Epoch 62/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2883 - val_loss: 0.2664
# Epoch 63/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2861 - val_loss: 0.2753
# Epoch 64/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2704 - val_loss: 0.2705
# Epoch 65/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2982 - val_loss: 0.2617
# Epoch 66/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2859 - val_loss: 0.2813
# Epoch 67/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2493 - val_loss: 0.2910
# Epoch 68/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2781 - val_loss: 0.2833
# Epoch 69/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2724 - val_loss: 0.2599
# Epoch 70/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2803 - val_loss: 0.2546
# Epoch 71/300
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2398 - val_loss: 0.2774
# Epoch 72/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2686 - val_loss: 0.3245
# Epoch 73/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2418 - val_loss: 0.3035
# Epoch 74/300
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2675 - val_loss: 0.2695
# Epoch 75/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2583 - val_loss: 0.2701
# Epoch 76/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2523 - val_loss: 0.2910
# Epoch 77/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2255 - val_loss: 0.2730
# Epoch 78/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2290 - val_loss: 0.3342
# Epoch 79/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2330 - val_loss: 0.2324
# Epoch 80/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2343 - val_loss: 0.2715
# Epoch 81/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2644 - val_loss: 0.2793
# Epoch 82/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2142 - val_loss: 0.3107
# Epoch 83/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2158 - val_loss: 0.2808
# Epoch 84/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2342 - val_loss: 0.2987
# Epoch 85/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2411 - val_loss: 0.2722
# Epoch 86/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2144 - val_loss: 0.3098
# Epoch 87/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2256 - val_loss: 0.2765
# Epoch 88/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2121 - val_loss: 0.3359
# Epoch 89/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1971 - val_loss: 0.2636
# Epoch 90/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2202 - val_loss: 0.2548
# Epoch 91/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1947 - val_loss: 0.2576
# Epoch 92/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2072 - val_loss: 0.3388
# Epoch 93/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2222 - val_loss: 0.3856
# Epoch 94/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2076 - val_loss: 0.4386
# Epoch 95/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2310 - val_loss: 0.3058
# Epoch 96/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1787 - val_loss: 0.2667
# Epoch 97/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2280 - val_loss: 0.3029
# Epoch 98/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1766 - val_loss: 0.3805
# Epoch 99/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1975 - val_loss: 0.4003
# Epoch 100/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1967 - val_loss: 0.4214
# Epoch 101/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2214 - val_loss: 0.4309
# Epoch 102/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2078 - val_loss: 0.4666
# Epoch 103/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1799 - val_loss: 0.4889
# Epoch 104/300
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1825 - val_loss: 0.3727
# Epoch 105/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2008 - val_loss: 0.3229
# Epoch 106/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1833 - val_loss: 0.3856
# Epoch 107/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1893 - val_loss: 0.5042
# Epoch 108/300
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1750 - val_loss: 0.2980
# Epoch 109/300
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0917Restoring model weights from the end of the best epoch.
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1877 - val_loss: 0.3764
# Epoch 00109: early stopping

# %%
os.chdir('../')### OBTAIN PREDICTIONS ###

pred_simple = simple_model.predict_generator(generator_test)
pred_simple = scaler_y.inverse_transform(pred_simple)

# %%
plt.plot(pred_simple[:,0])

# %%
### COMPUTE METRICS ON TEST DATA ###

diz_error_lstm, diz_ac_lstm = {}, {}
diz_error_var_lstm, diz_ac_var_lstm = {}, {}


for i,col in enumerate(data.columns):
    
    error = mean_absolute_error(true[:,i], pred_simple[:,i])
    diz_error_lstm[col] = error
    
    error = mean_absolute_error(true[:,i], pred[:,i])
    diz_error_var_lstm[col] = error
    
    ac = autocor_pred(true[:,i], pred_simple[:,i])
    diz_ac_lstm[col] = ac
    
    ac = autocor_pred(true[:,i], pred[:,i])
    diz_ac_var_lstm[col] = ac

# %%
### COMPUTE METRICS ON TEST DATA ###

diz_error_lstm2, diz_ac_lstm2 = {}, {}
diz_error_var_lstm2, diz_ac_var_lstm2 = {}, {}


for i,col in enumerate(data.columns):
    
    error = mean_squared_error(true[:,i], pred_simple[:,i])
    diz_error_lstm2[col] = error
    
    error = mean_squared_error(true[:,i], pred[:,i])
    diz_error_var_lstm2[col] = error
    
    ac = autocor_pred(true[:,i], pred_simple[:,i])
    diz_ac_lstm2[col] = ac
    
    ac = autocor_pred(true[:,i], pred[:,i])
    diz_ac_var_lstm2[col] = ac

# %%
plt.figure(figsize=(14,5))
plt.bar(np.arange(len(diz_error_lstm))-0.15, diz_error_lstm.values(), alpha=0.5, width=0.3, label='lstm')
plt.bar(np.arange(len(diz_error_var_lstm))+0.15, diz_error_var_lstm.values(), alpha=0.5, width=0.3, label='var_lstm')
plt.xticks(range(len(diz_error_lstm)), diz_error_lstm.keys())
plt.ylabel('MAE'); plt.legend()
np.set_printoptions(False)

# %%
plt.figure(figsize=(14,5))
plt.bar(np.arange(len(diz_error_lstm2))-0.15, diz_error_lstm2.values(), alpha=0.5, width=0.3, label='lstm')
plt.bar(np.arange(len(diz_error_var_lstm2))+0.15, diz_error_var_lstm2.values(), alpha=0.5, width=0.3, label='var_lstm')
plt.xticks(range(len(diz_error_lstm2)), diz_error_lstm2.keys())
plt.ylabel('MSE'); plt.legend()
np.set_printoptions(False)

# %%
plt.figure(figsize=(14,5))
plt.bar(np.arange(len(diz_ac_lstm))-0.15, diz_ac_lstm.values(), alpha=0.5, width=0.3, label='lstm')
plt.bar(np.arange(len(diz_ac_var_lstm))+0.15, diz_ac_var_lstm.values(), alpha=0.5, width=0.3, label='var_lstm')
plt.xticks(range(len(diz_ac_lstm)), diz_ac_lstm.keys())
plt.ylabel('correlation lag1'); plt.legend()
np.set_printoptions(False)

# %%
import numpy as np
import pmdarima as pm
from pmdarima.datasets import load_wineind

# this is a dataset from R
wineind = load_wineind().astype(np.float64)

# fit stepwise auto-ARIMA
stepwise_fit = pm.auto_arima(wineind, start_p=1, start_q=1,
                             max_p=3, max_q=3, m=12,
                             start_P=0, seasonal=True,
                             d=1, D=1, trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=3066.760, BIC=3082.229, Time=0.425 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=3133.376, BIC=3139.564, Time=0.011 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=3099.734, BIC=3112.109, Time=0.097 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=3066.930, BIC=3079.305, Time=0.101 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=3131.408, BIC=3134.502, Time=0.020 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=3088.088, BIC=3100.463, Time=0.072 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=3067.459, BIC=3086.022, Time=0.601 seconds
# Fit ARIMA(1,1,1)x(0,1,2,12) [intercept=True]; AIC=3068.000, BIC=3086.563, Time=0.407 seconds
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=3071.925, BIC=3087.394, Time=0.183 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=3068.265, BIC=3089.922, Time=2.080 seconds
# Near non-invertible roots for order (1, 1, 1)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=3094.571, BIC=3106.946, Time=0.123 seconds
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=3067.447, BIC=3086.010, Time=0.253 seconds
# Fit ARIMA(1,1,2)x(0,1,1,12) [intercept=True]; AIC=3066.742, BIC=3085.305, Time=0.324 seconds
# Fit ARIMA(1,1,2)x(0,1,0,12) [intercept=True]; AIC=3090.957, BIC=3106.426, Time=0.099 seconds
# Fit ARIMA(1,1,2)x(1,1,1,12) [intercept=True]; AIC=3067.937, BIC=3089.594, Time=0.472 seconds
# Fit ARIMA(1,1,2)x(0,1,2,12) [intercept=True]; AIC=3067.731, BIC=3089.387, Time=0.622 seconds
# Fit ARIMA(1,1,2)x(1,1,0,12) [intercept=True]; AIC=3072.473, BIC=3091.036, Time=0.289 seconds
# Fit ARIMA(1,1,2)x(1,1,2,12) [intercept=True]; AIC=3068.627, BIC=3093.377, Time=1.898 seconds
# Near non-invertible roots for order (1, 1, 2)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(0,1,2)x(0,1,1,12) [intercept=True]; AIC=3066.787, BIC=3082.256, Time=0.134 seconds
# Fit ARIMA(2,1,2)x(0,1,1,12) [intercept=True]; AIC=3068.673, BIC=3090.330, Time=0.419 seconds
# Fit ARIMA(1,1,3)x(0,1,1,12) [intercept=True]; AIC=3068.810, BIC=3090.467, Time=0.410 seconds
# Fit ARIMA(0,1,3)x(0,1,1,12) [intercept=True]; AIC=3066.742, BIC=3085.305, Time=0.576 seconds
# Fit ARIMA(2,1,3)x(0,1,1,12) [intercept=True]; AIC=3070.634, BIC=3095.384, Time=1.094 seconds
# Total fit time: 10.720 seconds

# %%
# fit stepwise auto-ARIMA
stepwise_fit = pm.auto_arima(data['Inv'], start_p=1, start_q=1,
                             max_p=3, max_q=3, m=12,
                             start_P=0, seasonal=True,
                             d=1, D=1, trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=-118.606, BIC=-102.089, Time=0.776 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=22.625, BIC=29.231, Time=0.024 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=-48.820, BIC=-35.606, Time=0.231 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=-96.344, BIC=-83.131, Time=0.780 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=20.629, BIC=23.932, Time=0.018 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=-7.666, BIC=5.547, Time=0.135 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=-116.603, BIC=-96.783, Time=1.006 seconds
# Near non-invertible roots for order (1, 1, 1)(1, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,1)x(0,1,2,12) [intercept=True]; AIC=-116.409, BIC=-96.589, Time=1.992 seconds
# Near non-invertible roots for order (1, 1, 1)(0, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=-53.505, BIC=-36.988, Time=0.377 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=-115.047, BIC=-91.924, Time=2.439 seconds
# Near non-invertible roots for order (1, 1, 1)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=-110.605, BIC=-97.392, Time=0.811 seconds
# Near non-invertible roots for order (1, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=-121.065, BIC=-101.246, Time=1.100 seconds
# Near non-invertible roots for order (2, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(1,1,2)x(0,1,1,12) [intercept=True]; AIC=-120.179, BIC=-100.359, Time=1.400 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(0,1,0)x(0,1,1,12) [intercept=True]; AIC=-75.918, BIC=-66.008, Time=0.511 seconds
# Near non-invertible roots for order (0, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(0,1,2)x(0,1,1,12) [intercept=True]; AIC=-117.258, BIC=-100.741, Time=1.000 seconds
# Near non-invertible roots for order (0, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=-122.773, BIC=-106.257, Time=0.897 seconds
# Near non-invertible roots for order (2, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(2,1,2)x(0,1,1,12) [intercept=True]; AIC=-119.066, BIC=-95.943, Time=1.286 seconds
# Near non-invertible roots for order (2, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Total fit time: 14.792 seconds

# %%
import pickle
# Serialize with Pickle
with open('arima.pkl', 'wb') as pkl:
    pickle.dump(stepwise_fit, pkl)



# Now read it back and make a prediction
with open('arima.pkl', 'rb') as pkl:
    pickle_preds = pickle.load(pkl).predict(n_periods=5)

# %%
# You can still make predictions from the model at this point
preds = stepwise_fit.predict(n_periods=12)

# %%
plt.plot(preds)

# %%
from pmdarima.arima.utils import ndiffs

# Estimate the number of differences using an ADF test:
n_adf = ndiffs(data['Ind'], test='adf')  # -> 0

n_adf
# Out:
# 0

# %%
# Or a KPSS test (auto_arima default):
n_kpss = ndiffs(data['Com'], test='kpss')  # -> 0
n_kpss
# Out:
# 1

# %%
pm.plot_acf(data['Inf'])

# %%
pm.plot_pacf(data['Inf'])

# %%
col = data.columns[0]

# usa o pacote pmdarima para determinar a ordem de diferenciação
# da variável endógena
period_adf = ndiffs(data[col], test='adf')
period_kpss = ndiffs(data[col], test='adf')

if period_adf > period_kpss:
    period = period_adf
else:
    period = period_kpss



#df_external = data[['Agr','Ind','Inf','Com']]

### modelos de séries temporais
#ts_model = TS_Models()

### modelos de redes neurais
#nn_model = Models()
#nn_model.set_neurons(300)

### SPLIT TRAIN TEST ###

train_date = data.index[:int(len(data)*split)]
train = data[:int(len(data)*split)].copy()

test_date = data.index[int(len(data)*split):]
test = data[int(len(data)*split):].copy()

train= pd.DataFrame(train)
test = pd.DataFrame(test)

### PLOT ORIGINAL SERIES ###

#plot_series(train_date, train, test_date, test, data.columns[0])


### PLOT AUTOCORRELATION ###


#ts_model.plot_autocor(data.columns[0], train)

### OPERATE DIFFERENTIATION ###

df_diff = data.diff(period).dropna()
#df_external = df_external.iloc[period:].copy()


### SPLIT DIFFERENTIAL DATA IN TRAIN AND TEST ###

train_diff = df_diff.iloc[:len(train)-period,:].copy()
test_diff = df_diff.iloc[len(train)-period:,:].copy()

train_init = data.iloc[:len(train)-period,:].copy()
test_init = data.iloc[len(train)-period:-period,:].copy()

#train_ext = df_external.iloc[:len(train)-period,:].copy()
#test_ext = df_external.iloc[len(train)-period:,:].copy()


## PLOT DIFFERENTIAL SERIES ###


#ts_model.plot_autocor(data.columns[0], train_diff)

### FIND BEST ARIMA ###
arima_result = pm.auto_arima(data[col], start_p=1, start_q=1,
                             max_p=5, max_q=5, m=12,
                             start_P=0, seasonal=True,
                             d=1, D=1, trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise

### RETRIVE PREDICTION AND OBTAIN THE CORRESPONDING ACTUAL VALUES ###
steps = forward
date = train_date[-1]
forward = test.shape[0]
date_range = pd.date_range(date, periods=forward+1, freq='M', closed='right')
pred = arima_result.predict(steps)
#init = prior_init.loc[0].tail(period).values

if steps > period:
    id_period = list(range(period))*(steps//period)
    id_period = id_period + list(range(steps-len(id_period)))
else:
    id_period = list(range(steps))

#final_pred = np.zeros((steps, prior.shape[1]))
final_pred = np.zeros((steps))

for j, (i,p) in enumerate(zip(id_period, pred)):

    #final_pred[j] = init[i]+p
    final_pred[j] = p
final_true = data['Inv'].loc[date_range]

### PLOT ACTUAL vs PREDICTION ###



plt.figure(figsize=(16,4))
plt.plot(date_range, final_pred[:], c='green', label='prediction ARIMA')
plt.plot(date_range, final_true.values, c='orange', label='true')
plt.ylabel('Inv'); plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=-118.606, BIC=-102.089, Time=0.761 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=22.625, BIC=29.231, Time=0.025 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=-48.820, BIC=-35.606, Time=0.215 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=-96.344, BIC=-83.131, Time=0.744 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=20.629, BIC=23.932, Time=0.017 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=-7.666, BIC=5.547, Time=0.130 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=-116.603, BIC=-96.783, Time=0.934 seconds
# Near non-invertible roots for order (1, 1, 1)(1, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,1)x(0,1,2,12) [intercept=True]; AIC=-116.409, BIC=-96.589, Time=1.838 seconds
# Near non-invertible roots for order (1, 1, 1)(0, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=-53.505, BIC=-36.988, Time=0.326 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=-115.047, BIC=-91.924, Time=2.009 seconds
# Near non-invertible roots for order (1, 1, 1)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=-110.605, BIC=-97.392, Time=0.669 seconds
# Near non-invertible roots for order (1, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=-121.065, BIC=-101.246, Time=0.963 seconds
# Near non-invertible roots for order (2, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(1,1,2)x(0,1,1,12) [intercept=True]; AIC=-120.179, BIC=-100.359, Time=1.274 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(0,1,0)x(0,1,1,12) [intercept=True]; AIC=-75.918, BIC=-66.008, Time=0.483 seconds
# Near non-invertible roots for order (0, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(0,1,2)x(0,1,1,12) [intercept=True]; AIC=-117.258, BIC=-100.741, Time=0.991 seconds
# Near non-invertible roots for order (0, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=-122.773, BIC=-106.257, Time=0.832 seconds
# Near non-invertible roots for order (2, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(2,1,2)x(0,1,1,12) [intercept=True]; AIC=-119.066, BIC=-95.943, Time=1.191 seconds
# Near non-invertible roots for order (2, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Total fit time: 13.409 seconds

# %%
### GET TRAIN VALIDATION AND TEST DATA FOR NEURAL NETWORK ###
t = train
X = final_pred

# %%
train_init

# %%
best_order = arima_result.get_params()['order'][0]
train = train['Inv'].iloc[period+best_order:].values
# Out:
# array([18., 18., 18., 18., 18., 18., 18., 18., 18., 17., 17., 17., 17.,
#        16., 16., 16., 16., 16., 16., 17., 17., 17., 17., 17., 17., 17.,
#        18., 18., 17., 17., 17., 17., 17., 17., 17., 17., 17., 17., 17.,
#        17., 17., 17., 17., 17., 17., 17., 17., 17., 17., 17., 17., 17.,
#        17., 17., 17., 17., 17., 17., 18., 18., 18., 18., 18., 18., 18.,
#        18., 18., 19., 19., 19., 19., 19., 19., 20., 20., 20., 20., 19.,
#        19., 19., 18., 18., 18., 18., 19., 19., 19., 19., 20., 20., 20.,
#        20., 20., 20., 20., 21., 21., 21., 21., 21., 21., 21., 20., 21.,
#        21., 21., 21., 21., 20., 21., 21., 21., 21., 21., 21., 21., 21.,
#        21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21.,
#        21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 20.,
#        20., 20., 20., 20., 19., 19., 19., 19., 19., 19., 19., 19., 18.,
#        17.])

# %%
print(train.shape)
print(test.shape)
print(X.shape)
# Out:
# (157,)
# (54, 5)
# (54,)

# %%
y_train_var = np.concatenate([X,train_init['Inv'].iloc[best_order:].values])
X_train = np.concatenate([train_diff.iloc[best_order:].values, train_ext.iloc[best_order:].values], axis=1)
X_train_var = X

y_val = y_train[int(len(X)*split):]
y_val_var = y_train_var[int(len(X)*split):]
X_val = X_train[int(len(X)*split):]
X_val_var = X_train_var[int(len(X)*split):]

y_train = y_train[:int(len(X)*split)]
y_train_var = y_train_var[:int(len(X)*split)]
X_train = X_train[:int(len(X)*split)]
X_train_var = X_train_var[:int(len(X)*split)]

y_test = test.values
X_test = np.concatenate([test_diff.values, test_ext.values], axis=1)

# %%
y_train_var
# Out:
# array([15., 15., 15., 15., 15., 15., 14., 14., 14., 14., 14., 14., 14.,
#        14., 14., 14., 14., 14., 14., 14., 14., 14., 13., 13., 13., 13.,
#        13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 12., 12., 12.,
#        12.])

# %%
### SCALE DATA ###

scaler_y = StandardScaler()
scaler = StandardScaler()

y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_train_var = scaler_y.transform(y_train_var.reshape(-1,1))
y_val = scaler_y.transform(y_val.reshape(-1,1))
y_val_var = scaler_y.transform(y_val_var.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

X_train = scaler.fit_transform(X_train.reshape(-1,1))
X_train_var = scaler.transform(X_train_var.reshape(-1,1))
X_val = scaler.transform(X_val.reshape(-1,1))
X_val_var = scaler.transform(X_val_var.reshape(-1,1))
X_test = scaler.transform(X_test.reshape(-1,1))

# %%
X_train.shape
# Out:
# (360, 1)

# %%
seq_length = int(best_order * 1.5)
batch = int(seq_length * 1.5)
generator_train = TimeseriesGenerator(X_train, y_train, length=seq_length, batch_size=batch)
generator_train_var = TimeseriesGenerator(X_train_var, y_train_var, length=seq_length, batch_size=batch)
generator_val = TimeseriesGenerator(X_val, y_val, length=seq_length, batch_size=batch)
generator_val_var = TimeseriesGenerator(X_val_var, y_val_var, length=seq_length, batch_size=batch)
generator_test = TimeseriesGenerator(X_test, y_test, length=seq_length, batch_size=batch)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-5ab695bcfd3d> in <module>
#       1 seq_length = int(best_order * 1.5)
#       2 batch = int(seq_length * 1.5)
# ----> 3 generator_train = TimeseriesGenerator(X_train, y_train, length=seq_length, batch_size=batch)
#       4 generator_train_var = TimeseriesGenerator(X_train_var, y_train_var, length=seq_length, batch_size=batch)
#       5 generator_val = TimeseriesGenerator(X_val, y_val, length=seq_length, batch_size=batch)
#
# ~/anaconda3/lib/python3.7/site-packages/keras_preprocessing/sequence.py in __init__(self, data, targets, length, sampling_rate, stride, start_index, end_index, shuffle, reverse, batch_size)
#     334                              ' of same length. '
#     335                              'Data length is {}'.format(len(data)) +
# --> 336                              ' while target length is {}'.format(len(targets)))
#     337
#     338         self.data = data
#
# ValueError: Data and targets have to be of same length. Data length is 360 while target length is 40
